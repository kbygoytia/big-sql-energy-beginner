# %%
import pandas as pd

df_customers = pd.read_csv("customers.csv")
display(df_customers.head())
# Out:
#    id first_name last_name         address state         city  \
# 0   1       John       Doe     123 Main St    NY     New York
# 1   2       Jane     Smith     456 Oak Ave    CA  Los Angeles
# 2   3      David       Lee      789 Elm St    IL      Chicago
# 3   4      Sarah     Jones    1010 Pine St    TX      Houston
# 4   5    Michael     Brown  1111 Willow St    AZ      Phoenix
#
#                email phone_number  gender
# 0  user1@example.com  928-111-813    Male
# 1  user2@example.com  386-874-247  Female
# 2  user3@example.com  242-567-850    Male
# 3  user4@example.com  406-195-357    Male
# 4  user5@example.com  682-233-760    Male

# %%
SELECT * FROM "df_customers";
# Out:
#   Cell In[14], line 1
#     SELECT * FROM "df_customers";
#                   ^
# SyntaxError: invalid syntax
